# %%
from dotenv import load_dotenv
import os
import requests
import boto3
import json
import datetime
from urllib.parse import quote, urlparse


load_dotenv()  # otomatis baca file .env di direktori sekarang

print('START TRANSACTION; -- Mulai transaction')

# 1. Konfigurasi Kredensial
s3 = boto3.client(
    's3',
    endpoint_url=os.getenv("URL_ENDPOINT"),
    aws_access_key_id=os.getenv("AWS_ACCESS_KEY_ID"),
    aws_secret_access_key=os.getenv(
        "AWS_SECRET_KEY_ID")
)

def escape_sql_string(value):
    # Escape single quotes by doubling them
    return value.replace("'", "`")

def escape_ampersand(url):
    # Sebelumnya ada return, dan harus dihapus agar semua karakter bisa dicheck.
    # Ini sebenarnya gak dipakai.
    if "&" in url:
        url = url.replace("&", "%26")
    if "☆" in url:
        url = url.replace("☆", "%E2%98%86")
    if " " in url:
        url = url.replace(" ", "%20")
    if "⁇" in url:
        url = url.replace("⁇", "%E2%81%87")
    if "’" in url:
        url = url.replace("’", "%E2%80%99")
    if "⁚" in url:
        url = url.replace("⁚", "%E2%81%9A")
    if "⁄" in url:
        url = url.replace("⁄", "%E2%81%84")
    return url

def escape_url(url):
    # Mengencode karakter khusus lainnya menggunakan urllib
    return quote(url, safe=":/")

def get_artist_from_title(title, list_title_artist):
    """Fungsi untuk mencocokkan judul dan menemukan artis yang sesuai."""
    for item in list_title_artist:
        # Pisahkan berdasarkan ' --- '
        song_title, artist = item.split(' --- ')
        if title.lower() == song_title.lower():  # Cocokkan tanpa memperhatikan huruf besar/kecil
            return artist
    return "Unknown Artist"  # Return "Unknown Artist" string jika tidak ditemukan


def get_match_title_from_name(title, list_index_title):
    """Fungsi untuk mencocokkan index dan menemukan judul yang sesuai."""
    for item in list_index_title:
        # Pisahkan berdasarkan ' --- '
        song_title, artist = item.split(' --- ')
        if title.lower() == song_title.lower():  # Cocokkan tanpa memperhatikan huruf besar/kecil
            return artist
    return "Unknown Title"  # Return "Unknown Title" string jika tidak ditemukan

def get_sql_query_insert_music(bucket_name, folder_target, folder_name):
    total_jumlah_file = 0
    # Daftar pasangan nama lagu dan artis
    list_title_artist = []
    # Daftar pasangan nama lagu dan index
    list_index_title = []
    list_cover = []

    category = ""
    artist = ""
    album_artist = ""
    album = ''

    is_dynamic_artist = False
    is_dynamic_title = False
    disc = 0

    # Collecting each row of values
    values = []
    playlist_value = []

    # Starting timestamp for date_added
    base_time = datetime.datetime.now().replace(microsecond=0)

    # Base SQL INSERT statement template
    insert_statement_template = "INSERT INTO musics (id_music, link_gdrive, title, artist, cover, uploader, is_suspicious, disc_number) VALUES \n"
    playlist_insert_statement_template = "INSERT INTO `albums` (`uid`, `name`, `image`, `author`, `have_disc`) VALUES \n"
    favorite = "0"

    try:
        # 2. Request Data (List Objects)
        response = s3.list_objects_v2(
            Bucket=bucket_name,
            Prefix=folder_target  # Ini filternya (mirip buka folder)
        )

        # 3. Parsing Hasil
        if 'Contents' in response:
            # Langsung ambil daftar cover image
            IMAGE_EXTS = {'.jpg', '.jpeg', '.png', '.webp'}
            # Masukkan ke dalam list_cover
            list_cover.extend(
                f"cdncloudflare/{(obj['Key'])}"
                for obj in response.get('Contents', [])
                if os.path.splitext(obj['Key'])[1].lower() in IMAGE_EXTS
                # Filter untuk memastikan cover image adalah main cover, bukan cover dari sub-folder.
                and (os.path.splitext(obj['Key'])[0]).split("/")[-2] == folder_name
            )
            # Setelah itu baru proses file musik
            for obj in response['Contents']:
                key = obj['Key']
                
                # Membersihkan nama file dari prefix agar terlihat rapi
                nama_file = key.replace(folder_target, "")
                
                # if nama_file: # Mencegah folder itu sendiri ikut terprint
                # print(f"- {key} (Size: {size} bytes) - {last_modified}")
                nama_file = key.replace(" ", "%20")
                # print(f"cdncloudflare/{nama_file}")
                if (".here.txt" in key):
                    txt_url = f"https://cdn.sibeux.my.id/{nama_file}"
                    response = requests.get(txt_url)
                    # Secara eksplisit set encoding ke 'utf-8' (agar teks non-alphabet bisa terbaca)
                    response.encoding = 'utf-8'
                    content = response.text
                    text_content = json.loads(content)
                    # Assign value ke variable album
                    category = text_content["category"]
                    album = text_content['title']
                    album = album.replace("'", "\'")
                    artist = text_content["author"]
                    album_artist = text_content["author"]
                    if text_content['disc'] != '0':
                        disc = int(text_content['disc']) - 1
                        if (text_content['1']) != []:
                            is_dynamic_artist = True
                            for i in range(disc+1):
                                list_title_artist.append(
                                    text_content[str(i+1)]
                                )
                    elif text_content['1'] != []:
                        is_dynamic_artist = True
                        list_title_artist.append(text_content["1"])
                    if text_content['music_name_index']['1'] != []:
                        is_dynamic_title = True
                        for i in range(disc+1):
                            list_index_title.append(
                                text_content['music_name_index'][str(i+1)]
                            )
                # Dapatkan cover image dari file yang ada di dalam folder
                ext = os.path.splitext(key)[1].lower()
                if ext in ['.mp3', '.flac', '.m4a', '.ogg', '.wav', '.acc']:
                    music_url = f"cdncloudflare/{nama_file}"
                    final_title = ""
                    file_name_without_ext = os.path.splitext(
                        ((urlparse(key).path).split("/"))[-1])[0]
                    # cari artist berdasarkan nama file
                    if is_dynamic_artist:
                        if disc == 0:
                            artist = get_artist_from_title(
                                file_name_without_ext, list_title_artist[0])
                        else:
                            # pisah berdasar slash
                            parts = music_url.split("/")
                            number = int(parts[-2])  # elemen sebelum nama file
                            artist = get_artist_from_title(
                                file_name_without_ext, list_title_artist[number-1])
                    # Cari judul berdasarkan index
                    if is_dynamic_title:
                        if disc == 0:
                            title_song = get_match_title_from_name(file_name_without_ext, list_index_title[0])
                            title_song = title_song.replace("\'", "\\'")
                        else:
                            # pisah berdasar slash
                            parts = music_url.split("/")
                            number = int(parts[-2])  # elemen sebelum nama file
                            title_song = get_match_title_from_name(file_name_without_ext, list_index_title[number-1])
                            title_song = title_song.replace("\'", "\\'")
                    # Tambahkan 7 jam menggunakan timedelta
                    # date_added = base_time + datetime.timedelta(hours=7)
                    date_added = base_time + datetime.timedelta()
                    date_added_str = date_added.strftime("%Y-%m-%d %H:%M:%S")
                    # Escape special characters in the values
                    artist = escape_sql_string(artist)
                    album = escape_sql_string(album)
                    date_added_str = escape_sql_string(date_added_str)
                    if is_dynamic_title == True:
                        final_title = title_song
                    else:
                        final_title = file_name_without_ext
                    cover_link = list_cover[0]
                    path = urlparse(key).path
                    parts = path.split("/")
                    target = parts[-2]  # folder sebelum nama file
                    x = 1
                    if (target.lower() != 'flac'):
                        x = target
                    query = f"(NULL, '{music_url}', '{final_title}', '{artist}', '{cover_link}', 'Cybeat', 'false', '{x}')"
                    values.append(query)

        else:
            print("Folder kosong atau tidak ditemukan.")

    except Exception as e:
        print(f"Terjadi Error: {e}")

    # Buat query statement untuk insert album
    cover_link = list_cover[0]
    cover_link = escape_sql_string(cover_link)
    have_disc = 0
    if disc > 0:
        have_disc = 1
    playlist_value.append(
        f"(NULL, '{album}', '{cover_link}', '{album_artist}', {have_disc})"
    )

    # Joining all values into the final SQL INSERT statement
    playlist_insert_statement = playlist_insert_statement_template + \
        ",\n".join(playlist_value) + ";"
    insert_statement = insert_statement_template + \
        ",\n".join(values) + ";"

    jumlah_file = len(values)
    total_jumlah_file += jumlah_file
    print(f'\n-- {jumlah_file} files\n')
    print(playlist_insert_statement)
    print('SET @new_album_id = LAST_INSERT_ID();')
    print(insert_statement)
    print('SET @first_new_song_id = LAST_INSERT_ID();')
    album_music_insert_statement = 'INSERT INTO album_musics (id_playlist, id_music) VALUES\n'
    category_album_insert_statement = 'INSERT INTO category_albums (album_id, category_id) VALUES\n'
    album_music_value = []
    for index in range(jumlah_file):
        album_music_value.append(f'(@new_album_id, @first_new_song_id + {index})')
    print(album_music_insert_statement + \
        ",\n".join(album_music_value) + ";")
    print(category_album_insert_statement + \
        f"(@new_album_id, {category});")
    print(f'\n-- total file: {total_jumlah_file}\n')


folder_name = ["5-instrumental/12-tsuetsurugi-music-collection-20260422-210353",
"5-instrumental/34-heroesrising-20260422-210327",
"5-instrumental/47-umaru-chan-ost-20260422-210409",
"5-instrumental/57-ngnl-ost-20260422-210437"
]
for index in range(len(folder_name)):
    folder_target = ''
    origin_folder_name = folder_name[index].replace("\\", "/").split('/')[1]
    # Akhiri dengan slash (/) untuk menandakan folder
    if folder_name[index][0] == '1':
        folder_target = f'files/music/indopride/{origin_folder_name}/'
    elif folder_name[index][0] == '2':
        folder_target = f'files/music/anisong/{origin_folder_name}/'
    elif folder_name[index][0] == '4':
        folder_target = f'files/music/worldwide/{origin_folder_name}/'
    elif folder_name[index][0] == '5':
        folder_target = f'files/music/instrumental/{origin_folder_name}/'
    bucket_name = 'cybeat-sibeux'
    get_sql_query_insert_music(bucket_name, folder_target, origin_folder_name)
print('COMMIT; -- Kalau semua sukses')
# ROLLBACK -- Kalau ada error di tengah2
# Out:
# START TRANSACTION; -- Mulai transaction
#
# -- 12 files
#
# INSERT INTO `albums` (`uid`, `name`, `image`, `author`, `have_disc`) VALUES
# (NULL, 'TV Anime "Tsue to Tsurugi no Wistoria" Music Collection', 'cdncloudflare/files/music/instrumental/12-tsuetsurugi-music-collection-20260422-210353/cover.jpg', 'Yuki Hayashi', 0);
# SET @new_album_id = LAST_INSERT_ID();
# INSERT INTO musics (id_music, link_gdrive, title, artist, cover, uploader, is_suspicious, disc_number) VALUES
# (NULL, 'cdncloudflare/files/music/instrumental/12-tsuetsurugi-music-collection-20260422-210353/flac/01.flac', 'Records of Rigarden', 'Yuki Hayashi', 'cdncloudflare/files/music/instrumental/12-tsuetsurugi-music-collection-20260422-210353/cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/12-tsuetsurugi-music-collection-20260422-210353/flac/02.flac', 'Wistoria: Wand and Sword', 'Yuki Hayashi', 'cdncloudflare/files/music/instrumental/12-tsuetsurugi-music-collection-20260422-210353/cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/12-tsuetsurugi-music-collection-20260422-210353/flac/03.flac', 'Elfaria\'s Theme', 'Yuki Hayashi', 'cdncloudflare/files/music/instrumental/12-tsuetsurugi-music-collection-20260422-210353/cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/12-tsuetsurugi-music-collection-20260422-210353/flac/04.flac', 'Rigarden Magical Academy', 'Yuki Hayashi', 'cdncloudflare/files/music/instrumental/12-tsuetsurugi-music-collection-20260422-210353/cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/12-tsuetsurugi-music-collection-20260422-210353/flac/05.flac', 'Colette\'s Theme', 'Yuki Hayashi', 'cdncloudflare/files/music/instrumental/12-tsuetsurugi-music-collection-20260422-210353/cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/12-tsuetsurugi-music-collection-20260422-210353/flac/06.flac', 'Goggles', 'Yuki Hayashi', 'cdncloudflare/files/music/instrumental/12-tsuetsurugi-music-collection-20260422-210353/cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/12-tsuetsurugi-music-collection-20260422-210353/flac/07.flac', 'Reminiscence', 'Yuki Hayashi', 'cdncloudflare/files/music/instrumental/12-tsuetsurugi-music-collection-20260422-210353/cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/12-tsuetsurugi-music-collection-20260422-210353/flac/08.flac', 'Calculated Prowess', 'Yuki Hayashi', 'cdncloudflare/files/music/instrumental/12-tsuetsurugi-music-collection-20260422-210353/cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/12-tsuetsurugi-music-collection-20260422-210353/flac/09.flac', 'Sion\'s Theme', 'Yuki Hayashi', 'cdncloudflare/files/music/instrumental/12-tsuetsurugi-music-collection-20260422-210353/cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/12-tsuetsurugi-music-collection-20260422-210353/flac/10.flac', 'Lihanna\'s Theme', 'Yuki Hayashi', 'cdncloudflare/files/music/instrumental/12-tsuetsurugi-music-collection-20260422-210353/cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/12-tsuetsurugi-music-collection-20260422-210353/flac/11.flac', 'Sword of Courage', 'Yuki Hayashi', 'cdncloudflare/files/music/instrumental/12-tsuetsurugi-music-collection-20260422-210353/cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/12-tsuetsurugi-music-collection-20260422-210353/flac/12.flac', 'Ever After', 'Yuki Hayashi', 'cdncloudflare/files/music/instrumental/12-tsuetsurugi-music-collection-20260422-210353/cover.jpg', 'Cybeat', 'false', '1');
# SET @first_new_song_id = LAST_INSERT_ID();
# INSERT INTO album_musics (id_playlist, id_music) VALUES
# (@new_album_id, @first_new_song_id + 0),
# (@new_album_id, @first_new_song_id + 1),
# (@new_album_id, @first_new_song_id + 2),
# (@new_album_id, @first_new_song_id + 3),
# (@new_album_id, @first_new_song_id + 4),
# (@new_album_id, @first_new_song_id + 5),
# (@new_album_id, @first_new_song_id + 6),
# (@new_album_id, @first_new_song_id + 7),
# (@new_album_id, @first_new_song_id + 8),
# (@new_album_id, @first_new_song_id + 9),
# (@new_album_id, @first_new_song_id + 10),
# (@new_album_id, @first_new_song_id + 11);
# INSERT INTO category_albums (album_id, category_id) VALUES
# (@new_album_id, 5);
#
# -- total file: 12
#
#
# -- 34 files
#
# INSERT INTO `albums` (`uid`, `name`, `image`, `author`, `have_disc`) VALUES
# (NULL, 'My Hero Academia THE MOVIE HEROES:RISING Original Soundtrack', 'cdncloudflare/files/music/instrumental/34-heroesrising-20260422-210327/Cover.jpg', 'Yuki Hayashi', 0);
# SET @new_album_id = LAST_INSERT_ID();
# INSERT INTO musics (id_music, link_gdrive, title, artist, cover, uploader, is_suspicious, disc_number) VALUES
# (NULL, 'cdncloudflare/files/music/instrumental/34-heroesrising-20260422-210327/flac/01.flac', 'HEROES VS. VILLANS', 'Yuki Hayashi', 'cdncloudflare/files/music/instrumental/34-heroesrising-20260422-210327/Cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/34-heroesrising-20260422-210327/flac/02.flac', 'Nine', 'Yuki Hayashi', 'cdncloudflare/files/music/instrumental/34-heroesrising-20260422-210327/Cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/34-heroesrising-20260422-210327/flac/03.flac', 'What is a Hero...', 'Yuki Hayashi', 'cdncloudflare/files/music/instrumental/34-heroesrising-20260422-210327/Cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/34-heroesrising-20260422-210327/flac/04.flac', 'The Recommended Hero Activity Project', 'Yuki Hayashi', 'cdncloudflare/files/music/instrumental/34-heroesrising-20260422-210327/Cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/34-heroesrising-20260422-210327/flac/05.flac', 'A Super Hero-esque Thing is Here!!', 'Yuki Hayashi', 'cdncloudflare/files/music/instrumental/34-heroesrising-20260422-210327/Cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/34-heroesrising-20260422-210327/flac/06.flac', 'The People of Nabu Island', 'Yuki Hayashi', 'cdncloudflare/files/music/instrumental/34-heroesrising-20260422-210327/Cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/34-heroesrising-20260422-210327/flac/07.flac', 'An Inherited Power', 'Yuki Hayashi', 'cdncloudflare/files/music/instrumental/34-heroesrising-20260422-210327/Cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/34-heroesrising-20260422-210327/flac/08.flac', 'Nine\'s Quirk', 'Yuki Hayashi', 'cdncloudflare/files/music/instrumental/34-heroesrising-20260422-210327/Cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/34-heroesrising-20260422-210327/flac/09.flac', 'Nine\'s Failure', 'Yuki Hayashi', 'cdncloudflare/files/music/instrumental/34-heroesrising-20260422-210327/Cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/34-heroesrising-20260422-210327/flac/10.flac', 'The Villains Appear', 'Yuki Hayashi', 'cdncloudflare/files/music/instrumental/34-heroesrising-20260422-210327/Cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/34-heroesrising-20260422-210327/flac/11.flac', 'You Chose the Wrong Person to Ridicule', 'Yuki Hayashi', 'cdncloudflare/files/music/instrumental/34-heroesrising-20260422-210327/Cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/34-heroesrising-20260422-210327/flac/12.flac', 'Deku and Katsuma', 'Yuki Hayashi', 'cdncloudflare/files/music/instrumental/34-heroesrising-20260422-210327/Cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/34-heroesrising-20260422-210327/flac/13.flac', 'Nine\'s Action', 'Yuki Hayashi', 'cdncloudflare/files/music/instrumental/34-heroesrising-20260422-210327/Cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/34-heroesrising-20260422-210327/flac/14.flac', 'The Villain\'s Surprise Attack', 'Yuki Hayashi', 'cdncloudflare/files/music/instrumental/34-heroesrising-20260422-210327/Cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/34-heroesrising-20260422-210327/flac/15.flac', 'Class A, Go Forth to Rescue!', 'Yuki Hayashi', 'cdncloudflare/files/music/instrumental/34-heroesrising-20260422-210327/Cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/34-heroesrising-20260422-210327/flac/16.flac', 'The Resistance of the Villains', 'Yuki Hayashi', 'cdncloudflare/files/music/instrumental/34-heroesrising-20260422-210327/Cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/34-heroesrising-20260422-210327/flac/17.flac', 'Outnumbered', 'Yuki Hayashi', 'cdncloudflare/files/music/instrumental/34-heroesrising-20260422-210327/Cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/34-heroesrising-20260422-210327/flac/18.flac', 'Nine\'s Tenacity', 'Yuki Hayashi', 'cdncloudflare/files/music/instrumental/34-heroesrising-20260422-210327/Cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/34-heroesrising-20260422-210327/flac/19.flac', 'The Strength of the Man Who Will Become No. 1', 'Yuki Hayashi', 'cdncloudflare/files/music/instrumental/34-heroesrising-20260422-210327/Cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/34-heroesrising-20260422-210327/flac/20.flac', 'The Island Citizen\'s Uncertaint', 'Yuki Hayashi', 'cdncloudflare/files/music/instrumental/34-heroesrising-20260422-210327/Cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/34-heroesrising-20260422-210327/flac/21.flac', 'Nine\'s Past', 'Yuki Hayashi', 'cdncloudflare/files/music/instrumental/34-heroesrising-20260422-210327/Cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/34-heroesrising-20260422-210327/flac/22.flac', 'Hearts Become One', 'Yuki Hayashi', 'cdncloudflare/files/music/instrumental/34-heroesrising-20260422-210327/Cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/34-heroesrising-20260422-210327/flac/23.flac', 'A Strategic Meeting', 'Yuki Hayashi', 'cdncloudflare/files/music/instrumental/34-heroesrising-20260422-210327/Cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/34-heroesrising-20260422-210327/flac/24.flac', 'Strategy Commence!', 'Yuki Hayashi', 'cdncloudflare/files/music/instrumental/34-heroesrising-20260422-210327/Cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/34-heroesrising-20260422-210327/flac/25.flac', 'Stop them with All Your Power!', 'Yuki Hayashi', 'cdncloudflare/files/music/instrumental/34-heroesrising-20260422-210327/Cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/34-heroesrising-20260422-210327/flac/26.flac', 'Fight Together', 'Yuki Hayashi', 'cdncloudflare/files/music/instrumental/34-heroesrising-20260422-210327/Cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/34-heroesrising-20260422-210327/flac/27.flac', 'Chimera', 'Yuki Hayashi', 'cdncloudflare/files/music/instrumental/34-heroesrising-20260422-210327/Cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/34-heroesrising-20260422-210327/flac/28.flac', 'To the Limit', 'Yuki Hayashi', 'cdncloudflare/files/music/instrumental/34-heroesrising-20260422-210327/Cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/34-heroesrising-20260422-210327/flac/29.flac', 'Nine\'s Yearning', 'Yuki Hayashi', 'cdncloudflare/files/music/instrumental/34-heroesrising-20260422-210327/Cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/34-heroesrising-20260422-210327/flac/30.flac', 'To Be the No. 1 Hero -Bakugo\'s Belief-', 'Yuki Hayashi', 'cdncloudflare/files/music/instrumental/34-heroesrising-20260422-210327/Cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/34-heroesrising-20260422-210327/flac/31.flac', 'Nine\'s Power', 'Yuki Hayashi', 'cdncloudflare/files/music/instrumental/34-heroesrising-20260422-210327/Cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/34-heroesrising-20260422-210327/flac/32.flac', 'Might+U', 'Yuki Hayashi', 'cdncloudflare/files/music/instrumental/34-heroesrising-20260422-210327/Cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/34-heroesrising-20260422-210327/flac/33.flac', 'An Inherited Heart', 'Yuki Hayashi', 'cdncloudflare/files/music/instrumental/34-heroesrising-20260422-210327/Cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/34-heroesrising-20260422-210327/flac/34.flac', 'Heroes Are Here', 'Yuki Hayashi', 'cdncloudflare/files/music/instrumental/34-heroesrising-20260422-210327/Cover.jpg', 'Cybeat', 'false', '1');
# SET @first_new_song_id = LAST_INSERT_ID();
# INSERT INTO album_musics (id_playlist, id_music) VALUES
# (@new_album_id, @first_new_song_id + 0),
# (@new_album_id, @first_new_song_id + 1),
# (@new_album_id, @first_new_song_id + 2),
# (@new_album_id, @first_new_song_id + 3),
# (@new_album_id, @first_new_song_id + 4),
# (@new_album_id, @first_new_song_id + 5),
# (@new_album_id, @first_new_song_id + 6),
# (@new_album_id, @first_new_song_id + 7),
# (@new_album_id, @first_new_song_id + 8),
# (@new_album_id, @first_new_song_id + 9),
# (@new_album_id, @first_new_song_id + 10),
# (@new_album_id, @first_new_song_id + 11),
# (@new_album_id, @first_new_song_id + 12),
# (@new_album_id, @first_new_song_id + 13),
# (@new_album_id, @first_new_song_id + 14),
# (@new_album_id, @first_new_song_id + 15),
# (@new_album_id, @first_new_song_id + 16),
# (@new_album_id, @first_new_song_id + 17),
# (@new_album_id, @first_new_song_id + 18),
# (@new_album_id, @first_new_song_id + 19),
# (@new_album_id, @first_new_song_id + 20),
# (@new_album_id, @first_new_song_id + 21),
# (@new_album_id, @first_new_song_id + 22),
# (@new_album_id, @first_new_song_id + 23),
# (@new_album_id, @first_new_song_id + 24),
# (@new_album_id, @first_new_song_id + 25),
# (@new_album_id, @first_new_song_id + 26),
# (@new_album_id, @first_new_song_id + 27),
# (@new_album_id, @first_new_song_id + 28),
# (@new_album_id, @first_new_song_id + 29),
# (@new_album_id, @first_new_song_id + 30),
# (@new_album_id, @first_new_song_id + 31),
# (@new_album_id, @first_new_song_id + 32),
# (@new_album_id, @first_new_song_id + 33);
# INSERT INTO category_albums (album_id, category_id) VALUES
# (@new_album_id, 5);
#
# -- total file: 34
#
#
# -- 47 files
#
# INSERT INTO `albums` (`uid`, `name`, `image`, `author`, `have_disc`) VALUES
# (NULL, 'TV Anime "Himouto! Umaru-chan" Original Soundtrack', 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/cover.jpg', 'Yasuhiro Misawa', 0);
# SET @new_album_id = LAST_INSERT_ID();
# INSERT INTO musics (id_music, link_gdrive, title, artist, cover, uploader, is_suspicious, disc_number) VALUES
# (NULL, 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/flac/01.flac', 'The Perfect High School Girl', 'Yasuhiro Misawa', 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/flac/02.flac', 'Umaru and Big Brother', 'Yasuhiro Misawa', 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/flac/03.flac', 'Himouto', 'Yasuhiro Misawa', 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/flac/04.flac', 'Big Brother\'s Everyday Routine', 'Yasuhiro Misawa', 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/flac/05.flac', 'I\'ll Get Serious Starting Next Year', 'Yasuhiro Misawa', 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/flac/06.flac', 'This Place is Heaven!', 'Yasuhiro Misawa', 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/flac/07.flac', 'An Utter Himouto', 'Yasuhiro Misawa', 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/flac/08.flac', 'Downtime', 'Yasuhiro Misawa', 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/flac/09.flac', 'I Still Wanna Lounge Around...', 'Yasuhiro Misawa', 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/flac/10.flac', 'Lollygagging Way of Life', 'Yasuhiro Misawa', 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/flac/11.flac', 'Regrets of Nighttime', 'Yasuhiro Misawa', 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/flac/12.flac', 'Disgruntled Umaru', 'Yasuhiro Misawa', 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/flac/13.flac', 'It\'s a Challenge!', 'Yasuhiro Misawa', 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/flac/14.flac', 'The Feast Shall Begin!', 'Yasuhiro Misawa', 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/flac/15.flac', 'Selfish Umaru', 'Yasuhiro Misawa', 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/flac/16.flac', 'The Beautiful Younger Sister', 'Yasuhiro Misawa', 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/flac/17.flac', 'Wolf in Sheep\'s Clothing', 'Yasuhiro Misawa', 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/flac/18.flac', 'Let\'s Go Have Fun', 'Yasuhiro Misawa', 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/flac/19.flac', 'Thrilling Night Journey', 'Yasuhiro Misawa', 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/flac/20.flac', 'Lonely Night Journey', 'Yasuhiro Misawa', 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/flac/21.flac', 'I Wish Time Would Stop, Right Now', 'Yasuhiro Misawa', 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/flac/22.flac', 'Umaru Rhythm No. 1', 'Yasuhiro Misawa', 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/flac/23.flac', 'Umaru Rhythm No. 2', 'Yasuhiro Misawa', 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/flac/24.flac', 'The Strongest Gamer', 'Yasuhiro Misawa', 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/flac/25.flac', 'Suggested Bluffing', 'Yasuhiro Misawa', 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/flac/26.flac', 'Is Big Brother Scared?', 'Yasuhiro Misawa', 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/flac/27.flac', 'Scared Dream', 'Yasuhiro Misawa', 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/flac/28.flac', 'Irritated Girl', 'Yasuhiro Misawa', 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/flac/29.flac', 'I\'ll Follow You Anywhere', 'Yasuhiro Misawa', 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/flac/30.flac', 'Japanet Commercial', 'Yasuhiro Misawa', 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/flac/31.flac', 'Japanet Girl Commercial', 'Yasuhiro Misawa', 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/flac/32.flac', 'Dekantea Commercial', 'Yasuhiro Misawa', 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/flac/33.flac', 'Troublesome Life', 'Yasuhiro Misawa', 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/flac/34.flac', 'Objection!', 'Yasuhiro Misawa', 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/flac/35.flac', 'Umaru Complementation Project', 'Yasuhiro Misawa', 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/flac/36.flac', 'Wasted Cola', 'Yasuhiro Misawa', 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/flac/37.flac', 'I Can\'t Decide All Alone', 'Yasuhiro Misawa', 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/flac/38.flac', 'Umaru-chan S', 'Yasuhiro Misawa', 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/flac/39.flac', 'A Road I Can\'t Recall', 'Yasuhiro Misawa', 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/flac/40.flac', 'Thank You, Big Brother', 'Yasuhiro Misawa', 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/flac/41.flac', 'Umaru is in a Bad Mood', 'Yasuhiro Misawa', 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/flac/42.flac', 'Day Off with Big Brother', 'Yasuhiro Misawa', 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/flac/43.flac', 'Fellow Younger Sisters', 'Yasuhiro Misawa', 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/flac/44.flac', 'Umaru\'s Summer Vacation', 'Yasuhiro Misawa', 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/flac/45.flac', 'My One and Only Younger Sister', 'Yasuhiro Misawa', 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/flac/46.flac', 'Let\'s Metamorphose Innovatingly -TV version-', 'Doma Umaru (CV: Aimi Tanaka)', 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/flac/47.flac', 'Days Spent in The Sun -TV version-', 'Imouto S', 'cdncloudflare/files/music/instrumental/47-umaru-chan-ost-20260422-210409/cover.jpg', 'Cybeat', 'false', '1');
# SET @first_new_song_id = LAST_INSERT_ID();
# INSERT INTO album_musics (id_playlist, id_music) VALUES
# (@new_album_id, @first_new_song_id + 0),
# (@new_album_id, @first_new_song_id + 1),
# (@new_album_id, @first_new_song_id + 2),
# (@new_album_id, @first_new_song_id + 3),
# (@new_album_id, @first_new_song_id + 4),
# (@new_album_id, @first_new_song_id + 5),
# (@new_album_id, @first_new_song_id + 6),
# (@new_album_id, @first_new_song_id + 7),
# (@new_album_id, @first_new_song_id + 8),
# (@new_album_id, @first_new_song_id + 9),
# (@new_album_id, @first_new_song_id + 10),
# (@new_album_id, @first_new_song_id + 11),
# (@new_album_id, @first_new_song_id + 12),
# (@new_album_id, @first_new_song_id + 13),
# (@new_album_id, @first_new_song_id + 14),
# (@new_album_id, @first_new_song_id + 15),
# (@new_album_id, @first_new_song_id + 16),
# (@new_album_id, @first_new_song_id + 17),
# (@new_album_id, @first_new_song_id + 18),
# (@new_album_id, @first_new_song_id + 19),
# (@new_album_id, @first_new_song_id + 20),
# (@new_album_id, @first_new_song_id + 21),
# (@new_album_id, @first_new_song_id + 22),
# (@new_album_id, @first_new_song_id + 23),
# (@new_album_id, @first_new_song_id + 24),
# (@new_album_id, @first_new_song_id + 25),
# (@new_album_id, @first_new_song_id + 26),
# (@new_album_id, @first_new_song_id + 27),
# (@new_album_id, @first_new_song_id + 28),
# (@new_album_id, @first_new_song_id + 29),
# (@new_album_id, @first_new_song_id + 30),
# (@new_album_id, @first_new_song_id + 31),
# (@new_album_id, @first_new_song_id + 32),
# (@new_album_id, @first_new_song_id + 33),
# (@new_album_id, @first_new_song_id + 34),
# (@new_album_id, @first_new_song_id + 35),
# (@new_album_id, @first_new_song_id + 36),
# (@new_album_id, @first_new_song_id + 37),
# (@new_album_id, @first_new_song_id + 38),
# (@new_album_id, @first_new_song_id + 39),
# (@new_album_id, @first_new_song_id + 40),
# (@new_album_id, @first_new_song_id + 41),
# (@new_album_id, @first_new_song_id + 42),
# (@new_album_id, @first_new_song_id + 43),
# (@new_album_id, @first_new_song_id + 44),
# (@new_album_id, @first_new_song_id + 45),
# (@new_album_id, @first_new_song_id + 46);
# INSERT INTO category_albums (album_id, category_id) VALUES
# (@new_album_id, 5);
#
# -- total file: 47
#
#
# -- 57 files
#
# INSERT INTO `albums` (`uid`, `name`, `image`, `author`, `have_disc`) VALUES
# (NULL, 'No Game, No Life Original Soundtrack', 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/Cover.jpg', 'Ayako Saso, Fumihisa Tanaka, Shinji Hosoe, Takahiro Eguchi', 1);
# SET @new_album_id = LAST_INSERT_ID();
# INSERT INTO musics (id_music, link_gdrive, title, artist, cover, uploader, is_suspicious, disc_number) VALUES
# (NULL, 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/1/01.flac', '=Oneself', 'Shiro (CV: Ai Kayano)', 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/Cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/1/02.flac', '=Oneself (Instrumental)', 'Shingo Yamazaki', 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/Cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/1/03.flac', 'Game Start', 'Shinji Hosoe', 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/Cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/1/04.flac', 'Gray Sky', 'Takahiro Eguchi', 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/Cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/1/05.flac', 'The Bluff', 'Takahiro Eguchi', 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/Cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/1/06.flac', 'Blue Sky', 'Takahiro Eguchi', 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/Cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/1/07.flac', 'Play White', 'Ayako Saso', 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/Cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/1/08.flac', 'Rainbow Sky', 'Takahiro Eguchi', 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/Cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/1/09.flac', 'Princess Stephanie', 'Ayako Saso', 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/Cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/1/10.flac', 'Time-Out', 'Takahiro Eguchi', 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/Cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/1/11.flac', 'Mode-Easy', 'Ayako Saso', 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/Cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/1/12.flac', 'Mode-Normal', 'Shinji Hosoe', 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/Cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/1/13.flac', 'Choisies', 'Ayako Saso', 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/Cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/1/14.flac', 'Criminal Connection', 'Shinji Hosoe', 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/Cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/1/15.flac', 'Thinking', 'Takahiro Eguchi', 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/Cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/1/16.flac', 'The Rules', 'Shinji Hosoe', 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/Cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/1/17.flac', 'Mode-Hard', 'Takahiro Eguchi', 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/Cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/1/18.flac', 'God of the Game', 'Ayako Saso', 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/Cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/1/19.flac', 'The Mystery', 'Takahiro Eguchi', 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/Cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/1/20.flac', 'Before I Met You', 'Takahiro Eguchi', 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/Cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/1/21.flac', 'Predown', 'Takahiro Eguchi', 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/Cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/2/01.flac', 'Light of Hope', 'Stephanie Dora (CV: Yoko Hikasa)', 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/Cover.jpg', 'Cybeat', 'false', '2'),
# (NULL, 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/2/02.flac', 'Light of Hope (Instrumental)', 'Nao Harada', 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/Cover.jpg', 'Cybeat', 'false', '2'),
# (NULL, 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/2/03.flac', 'Reverse', 'Ayako Saso', 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/Cover.jpg', 'Cybeat', 'false', '2'),
# (NULL, 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/2/04.flac', 'Hey, Brother', 'Takahiro Eguchi', 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/Cover.jpg', 'Cybeat', 'false', '2'),
# (NULL, 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/2/05.flac', 'Hey, Sister', 'Ayako Saso', 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/Cover.jpg', 'Cybeat', 'false', '2'),
# (NULL, 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/2/06.flac', 'Goofy Princess', 'Ayako Saso', 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/Cover.jpg', 'Cybeat', 'false', '2'),
# (NULL, 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/2/07.flac', 'Sister Complex', 'Fumihisa Tanaka', 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/Cover.jpg', 'Cybeat', 'false', '2'),
# (NULL, 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/2/08.flac', 'Mode-Very Easy', 'Takahiro Eguchi', 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/Cover.jpg', 'Cybeat', 'false', '2'),
# (NULL, 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/2/09.flac', 'Trick', 'Takahiro Eguchi', 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/Cover.jpg', 'Cybeat', 'false', '2'),
# (NULL, 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/2/10.flac', 'Speed +2', 'Takahiro Eguchi', 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/Cover.jpg', 'Cybeat', 'false', '2'),
# (NULL, 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/2/11.flac', 'Now, It\'s My Turn', 'Takahiro Eguchi', 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/Cover.jpg', 'Cybeat', 'false', '2'),
# (NULL, 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/2/12.flac', 'Press Enter Key', 'Takahiro Eguchi', 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/Cover.jpg', 'Cybeat', 'false', '2'),
# (NULL, 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/2/13.flac', 'Perfect!', 'Ayako Saso', 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/Cover.jpg', 'Cybeat', 'false', '2'),
# (NULL, 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/2/14.flac', 'Next Stage', 'Shinji Hosoe', 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/Cover.jpg', 'Cybeat', 'false', '2'),
# (NULL, 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/2/15.flac', 'Power +2', 'Ayako Saso', 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/Cover.jpg', 'Cybeat', 'false', '2'),
# (NULL, 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/2/16.flac', 'Winner', 'Shinji Hosoe', 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/Cover.jpg', 'Cybeat', 'false', '2'),
# (NULL, 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/2/17.flac', 'Moon X2', 'Shinji Hosoe', 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/Cover.jpg', 'Cybeat', 'false', '2'),
# (NULL, 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/2/18.flac', 'Not to be Saved', 'Takahiro Eguchi', 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/Cover.jpg', 'Cybeat', 'false', '2'),
# (NULL, 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/3/01.flac', 'Yes, my master my lord', 'Jibril (CV: Yukari Tamura)', 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/Cover.jpg', 'Cybeat', 'false', '3'),
# (NULL, 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/3/02.flac', 'Onegai Star Snyaiper', 'Izuna Hatsuse (CV: Miyuki Sawashiro)', 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/Cover.jpg', 'Cybeat', 'false', '3'),
# (NULL, 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/3/03.flac', 'Yes, my master my lord (Instrumental)', 'KEiGO Yo', 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/Cover.jpg', 'Cybeat', 'false', '3'),
# (NULL, 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/3/04.flac', 'Onegai Star Snyaiper (Instrumental)', 'y0c1e', 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/Cover.jpg', 'Cybeat', 'false', '3'),
# (NULL, 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/3/05.flac', 'Barrier', 'Ayako Saso', 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/Cover.jpg', 'Cybeat', 'false', '3'),
# (NULL, 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/3/06.flac', 'IZUNA', 'Takahiro Eguchi', 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/Cover.jpg', 'Cybeat', 'false', '3'),
# (NULL, 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/3/07.flac', 'Who is the winner', 'Shinji Hosoe', 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/Cover.jpg', 'Cybeat', 'false', '3'),
# (NULL, 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/3/08.flac', 'Maze', 'Takahiro Eguchi', 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/Cover.jpg', 'Cybeat', 'false', '3'),
# (NULL, 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/3/09.flac', 'Mode-VERY HARD', 'Takahiro Eguchi', 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/Cover.jpg', 'Cybeat', 'false', '3'),
# (NULL, 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/3/10.flac', 'The beast', 'Shinji Hosoe', 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/Cover.jpg', 'Cybeat', 'false', '3'),
# (NULL, 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/3/11.flac', 'TETO', 'Takahiro Eguchi', 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/Cover.jpg', 'Cybeat', 'false', '3'),
# (NULL, 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/3/12.flac', 'Empty', 'Ayako Saso', 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/Cover.jpg', 'Cybeat', 'false', '3'),
# (NULL, 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/3/13.flac', 'NO COLOUR', 'Takahiro Eguchi', 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/Cover.jpg', 'Cybeat', 'false', '3'),
# (NULL, 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/3/14.flac', 'I get you back', 'Fumihisa Tanaka', 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/Cover.jpg', 'Cybeat', 'false', '3'),
# (NULL, 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/3/15.flac', 'All of you is all of me', 'Fumihisa Tanaka', 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/Cover.jpg', 'Cybeat', 'false', '3'),
# (NULL, 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/3/16.flac', 'NO GAME NO LIFE', 'Takahiro Eguchi', 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/Cover.jpg', 'Cybeat', 'false', '3'),
# (NULL, 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/3/17.flac', 'after you wake up', 'Shinji Hosoe', 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/Cover.jpg', 'Cybeat', 'false', '3'),
# (NULL, 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/3/18.flac', 'Game over', 'Takahiro Eguchi', 'cdncloudflare/files/music/instrumental/57-ngnl-ost-20260422-210437/Cover.jpg', 'Cybeat', 'false', '3');
# SET @first_new_song_id = LAST_INSERT_ID();
# INSERT INTO album_musics (id_playlist, id_music) VALUES
# (@new_album_id, @first_new_song_id + 0),
# (@new_album_id, @first_new_song_id + 1),
# (@new_album_id, @first_new_song_id + 2),
# (@new_album_id, @first_new_song_id + 3),
# (@new_album_id, @first_new_song_id + 4),
# (@new_album_id, @first_new_song_id + 5),
# (@new_album_id, @first_new_song_id + 6),
# (@new_album_id, @first_new_song_id + 7),
# (@new_album_id, @first_new_song_id + 8),
# (@new_album_id, @first_new_song_id + 9),
# (@new_album_id, @first_new_song_id + 10),
# (@new_album_id, @first_new_song_id + 11),
# (@new_album_id, @first_new_song_id + 12),
# (@new_album_id, @first_new_song_id + 13),
# (@new_album_id, @first_new_song_id + 14),
# (@new_album_id, @first_new_song_id + 15),
# (@new_album_id, @first_new_song_id + 16),
# (@new_album_id, @first_new_song_id + 17),
# (@new_album_id, @first_new_song_id + 18),
# (@new_album_id, @first_new_song_id + 19),
# (@new_album_id, @first_new_song_id + 20),
# (@new_album_id, @first_new_song_id + 21),
# (@new_album_id, @first_new_song_id + 22),
# (@new_album_id, @first_new_song_id + 23),
# (@new_album_id, @first_new_song_id + 24),
# (@new_album_id, @first_new_song_id + 25),
# (@new_album_id, @first_new_song_id + 26),
# (@new_album_id, @first_new_song_id + 27),
# (@new_album_id, @first_new_song_id + 28),
# (@new_album_id, @first_new_song_id + 29),
# (@new_album_id, @first_new_song_id + 30),
# (@new_album_id, @first_new_song_id + 31),
# (@new_album_id, @first_new_song_id + 32),
# (@new_album_id, @first_new_song_id + 33),
# (@new_album_id, @first_new_song_id + 34),
# (@new_album_id, @first_new_song_id + 35),
# (@new_album_id, @first_new_song_id + 36),
# (@new_album_id, @first_new_song_id + 37),
# (@new_album_id, @first_new_song_id + 38),
# (@new_album_id, @first_new_song_id + 39),
# (@new_album_id, @first_new_song_id + 40),
# (@new_album_id, @first_new_song_id + 41),
# (@new_album_id, @first_new_song_id + 42),
# (@new_album_id, @first_new_song_id + 43),
# (@new_album_id, @first_new_song_id + 44),
# (@new_album_id, @first_new_song_id + 45),
# (@new_album_id, @first_new_song_id + 46),
# (@new_album_id, @first_new_song_id + 47),
# (@new_album_id, @first_new_song_id + 48),
# (@new_album_id, @first_new_song_id + 49),
# (@new_album_id, @first_new_song_id + 50),
# (@new_album_id, @first_new_song_id + 51),
# (@new_album_id, @first_new_song_id + 52),
# (@new_album_id, @first_new_song_id + 53),
# (@new_album_id, @first_new_song_id + 54),
# (@new_album_id, @first_new_song_id + 55),
# (@new_album_id, @first_new_song_id + 56);
# INSERT INTO category_albums (album_id, category_id) VALUES
# (@new_album_id, 5);
#
# -- total file: 57
#
# COMMIT; -- Kalau semua sukses
