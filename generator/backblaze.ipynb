# %%
from dotenv import load_dotenv
import os
import requests
import boto3
import json
import datetime
from urllib.parse import quote, urlparse


load_dotenv()  # otomatis baca file .env di direktori sekarang

print('START TRANSACTION; -- Mulai transaction')

# 1. Konfigurasi Kredensial
s3 = boto3.client(
    's3',
    endpoint_url=os.getenv("URL_ENDPOINT"),
    aws_access_key_id=os.getenv("AWS_ACCESS_KEY_ID"),
    aws_secret_access_key=os.getenv(
        "AWS_SECRET_KEY_ID")
)

def escape_sql_string(value):
    # Escape single quotes by doubling them
    return value.replace("'", "`")

def escape_ampersand(url):
    # Sebelumnya ada return, dan harus dihapus agar semua karakter bisa dicheck.
    # Ini sebenarnya gak dipakai.
    if "&" in url:
        url = url.replace("&", "%26")
    if "☆" in url:
        url = url.replace("☆", "%E2%98%86")
    if " " in url:
        url = url.replace(" ", "%20")
    if "⁇" in url:
        url = url.replace("⁇", "%E2%81%87")
    if "’" in url:
        url = url.replace("’", "%E2%80%99")
    if "⁚" in url:
        url = url.replace("⁚", "%E2%81%9A")
    if "⁄" in url:
        url = url.replace("⁄", "%E2%81%84")
    return url

def escape_url(url):
    # Mengencode karakter khusus lainnya menggunakan urllib
    return quote(url, safe=":/")

def get_artist_from_title(title, list_title_artist):
    """Fungsi untuk mencocokkan judul dan menemukan artis yang sesuai."""
    for item in list_title_artist:
        # Pisahkan berdasarkan ' --- '
        song_title, artist = item.split(' --- ')
        if title.lower() == song_title.lower():  # Cocokkan tanpa memperhatikan huruf besar/kecil
            return artist
    return "Unknown Artist"  # Return "Unknown Artist" string jika tidak ditemukan


def get_match_title_from_name(title, list_index_title):
    """Fungsi untuk mencocokkan index dan menemukan judul yang sesuai."""
    for item in list_index_title:
        # Pisahkan berdasarkan ' --- '
        song_title, artist = item.split(' --- ')
        if title.lower() == song_title.lower():  # Cocokkan tanpa memperhatikan huruf besar/kecil
            return artist
    return "Unknown Title"  # Return "Unknown Title" string jika tidak ditemukan

def get_sql_query_insert_music(bucket_name, folder_target, folder_name):
    total_jumlah_file = 0
    # Daftar pasangan nama lagu dan artis
    list_title_artist = []
    # Daftar pasangan nama lagu dan index
    list_index_title = []
    list_cover = []

    category = ""
    artist = ""
    album_artist = ""
    album = ''

    is_dynamic_artist = False
    is_dynamic_title = False
    disc = 0

    # Collecting each row of values
    values = []
    playlist_value = []

    # Starting timestamp for date_added
    base_time = datetime.datetime.now().replace(microsecond=0)

    # Base SQL INSERT statement template
    insert_statement_template = "INSERT INTO musics (id_music, link_gdrive, title, artist, cover, uploader, is_suspicious, disc_number) VALUES \n"
    playlist_insert_statement_template = "INSERT INTO `albums` (`uid`, `name`, `image`, `author`, `have_disc`) VALUES \n"
    favorite = "0"

    try:
        # 2. Request Data (List Objects)
        response = s3.list_objects_v2(
            Bucket=bucket_name,
            Prefix=folder_target  # Ini filternya (mirip buka folder)
        )

        # 3. Parsing Hasil
        if 'Contents' in response:
            # Langsung ambil daftar cover image
            IMAGE_EXTS = {'.jpg', '.jpeg', '.png', '.webp'}
            # Masukkan ke dalam list_cover
            list_cover.extend(
                f"cdncloudflare/{(obj['Key'])}"
                for obj in response.get('Contents', [])
                if os.path.splitext(obj['Key'])[1].lower() in IMAGE_EXTS
                # Filter untuk memastikan cover image adalah main cover, bukan cover dari sub-folder.
                and (os.path.splitext(obj['Key'])[0]).split("/")[-2] == folder_name
            )
            # Setelah itu baru proses file musik
            for obj in response['Contents']:
                key = obj['Key']
                
                # Membersihkan nama file dari prefix agar terlihat rapi
                nama_file = key.replace(folder_target, "")
                
                # if nama_file: # Mencegah folder itu sendiri ikut terprint
                # print(f"- {key} (Size: {size} bytes) - {last_modified}")
                nama_file = key.replace(" ", "%20")
                # print(f"cdncloudflare/{nama_file}")
                if (".here.txt" in key):
                    txt_url = f"https://cdn.sibeux.my.id/{nama_file}"
                    response = requests.get(txt_url)
                    # Secara eksplisit set encoding ke 'utf-8' (agar teks non-alphabet bisa terbaca)
                    response.encoding = 'utf-8'
                    content = response.text
                    text_content = json.loads(content)
                    # Assign value ke variable album
                    category = text_content["category"]
                    album = text_content['title']
                    album = album.replace("'", "\'")
                    artist = text_content["author"]
                    album_artist = text_content["author"]
                    if text_content['disc'] != '0':
                        disc = int(text_content['disc']) - 1
                        if (text_content['1']) != []:
                            is_dynamic_artist = True
                            for i in range(disc+1):
                                list_title_artist.append(
                                    text_content[str(i+1)]
                                )
                    elif text_content['1'] != []:
                        is_dynamic_artist = True
                        list_title_artist.append(text_content["1"])
                    if text_content['music_name_index']['1'] != []:
                        is_dynamic_title = True
                        for i in range(disc+1):
                            list_index_title.append(
                                text_content['music_name_index'][str(i+1)]
                            )
                # Dapatkan cover image dari file yang ada di dalam folder
                ext = os.path.splitext(key)[1].lower()
                if ext in ['.mp3', '.flac', '.m4a', '.ogg', '.wav', '.acc']:
                    music_url = f"cdncloudflare/{nama_file}"
                    final_title = ""
                    file_name_without_ext = os.path.splitext(
                        ((urlparse(key).path).split("/"))[-1])[0]
                    # cari artist berdasarkan nama file
                    if is_dynamic_artist:
                        if disc == 0:
                            artist = get_artist_from_title(
                                file_name_without_ext, list_title_artist[0])
                        else:
                            # pisah berdasar slash
                            parts = music_url.split("/")
                            number = int(parts[-2])  # elemen sebelum nama file
                            artist = get_artist_from_title(
                                file_name_without_ext, list_title_artist[number-1])
                    # Cari judul berdasarkan index
                    if is_dynamic_title:
                        if disc == 0:
                            title_song = get_match_title_from_name(file_name_without_ext, list_index_title[0])
                            title_song = title_song.replace("\'", "\\'")
                        else:
                            # pisah berdasar slash
                            parts = music_url.split("/")
                            number = int(parts[-2])  # elemen sebelum nama file
                            title_song = get_match_title_from_name(file_name_without_ext, list_index_title[number-1])
                            title_song = title_song.replace("\'", "\\'")
                    # Tambahkan 7 jam menggunakan timedelta
                    # date_added = base_time + datetime.timedelta(hours=7)
                    date_added = base_time + datetime.timedelta()
                    date_added_str = date_added.strftime("%Y-%m-%d %H:%M:%S")
                    # Escape special characters in the values
                    artist = escape_sql_string(artist)
                    album = escape_sql_string(album)
                    date_added_str = escape_sql_string(date_added_str)
                    if is_dynamic_title == True:
                        final_title = title_song
                    else:
                        final_title = file_name_without_ext
                    cover_link = list_cover[0]
                    path = urlparse(key).path
                    parts = path.split("/")
                    target = parts[-2]  # folder sebelum nama file
                    x = 1
                    if (target.lower() != 'flac'):
                        x = target
                    query = f"(NULL, '{music_url}', '{final_title}', '{artist}', '{cover_link}', 'Cybeat', 'false', '{x}')"
                    values.append(query)

        else:
            print("Folder kosong atau tidak ditemukan.")

    except Exception as e:
        print(f"Terjadi Error: {e}")

    # Buat query statement untuk insert album
    cover_link = list_cover[0]
    cover_link = escape_sql_string(cover_link)
    have_disc = 0
    if disc > 0:
        have_disc = 1
    playlist_value.append(
        f"(NULL, '{album}', '{cover_link}', '{album_artist}', {have_disc})"
    )

    # Joining all values into the final SQL INSERT statement
    playlist_insert_statement = playlist_insert_statement_template + \
        ",\n".join(playlist_value) + ";"
    insert_statement = insert_statement_template + \
        ",\n".join(values) + ";"

    jumlah_file = len(values)
    total_jumlah_file += jumlah_file
    print(f'\n-- {jumlah_file} files\n')
    print(playlist_insert_statement)
    print('SET @new_album_id = LAST_INSERT_ID();')
    print(insert_statement)
    print('SET @first_new_song_id = LAST_INSERT_ID();')
    album_music_insert_statement = 'INSERT INTO album_musics (id_playlist, id_music) VALUES\n'
    category_album_insert_statement = 'INSERT INTO category_albums (album_id, category_id) VALUES\n'
    album_music_value = []
    for index in range(jumlah_file):
        album_music_value.append(f'(@new_album_id, @first_new_song_id + {index})')
    print(album_music_insert_statement + \
        ",\n".join(album_music_value) + ";")
    print(category_album_insert_statement + \
        f"(@new_album_id, {category});")
    print(f'\n-- total file: {total_jumlah_file}\n')

with open('folder_list.txt', 'r') as f:
    folder_name = [line.strip() for line in f if line.strip()]
for index in range(len(folder_name)):
    folder_target = ''
    origin_folder_name = folder_name[index].replace("\\", "/").split('/')[1]
    # Akhiri dengan slash (/) untuk menandakan folder
    if folder_name[index][0] == '1':
        folder_target = f'files/music/indopride/{origin_folder_name}/'
    elif folder_name[index][0] == '2':
        folder_target = f'files/music/anisong/{origin_folder_name}/'
    elif folder_name[index][0] == '4':
        folder_target = f'files/music/worldwide/{origin_folder_name}/'
    elif folder_name[index][0] == '5':
        folder_target = f'files/music/instrumental/{origin_folder_name}/'
    bucket_name = 'cybeat-sibeux'
    get_sql_query_insert_music(bucket_name, folder_target, origin_folder_name)
print('COMMIT; -- Kalau semua sukses')
# ROLLBACK -- Kalau ada error di tengah2
# Out:
# START TRANSACTION; -- Mulai transaction
#
# -- 1 files
#
# INSERT INTO `albums` (`uid`, `name`, `image`, `author`, `have_disc`) VALUES
# (NULL, 'Anata o Fukou ni Izanaimasu ne Amazon Tokuten CD', 'cdncloudflare/files/music/anisong/1-amazon-20260422-222737/cover.jpg', 'Tuyu', 0);
# SET @new_album_id = LAST_INSERT_ID();
# INSERT INTO musics (id_music, link_gdrive, title, artist, cover, uploader, is_suspicious, disc_number) VALUES
# (NULL, 'cdncloudflare/files/music/anisong/1-amazon-20260422-222737/flac/01.mp3', 'Natsu no Kaze Goraikou (TUYU arrange ver.)', 'Tuyu', 'cdncloudflare/files/music/anisong/1-amazon-20260422-222737/cover.jpg', 'Cybeat', 'false', '1');
# SET @first_new_song_id = LAST_INSERT_ID();
# INSERT INTO album_musics (id_playlist, id_music) VALUES
# (@new_album_id, @first_new_song_id + 0);
# INSERT INTO category_albums (album_id, category_id) VALUES
# (@new_album_id, 2);
#
# -- total file: 1
#
#
# -- 1 files
#
# INSERT INTO `albums` (`uid`, `name`, `image`, `author`, `have_disc`) VALUES
# (NULL, 'Anata o Fukou ni Izanaimasu ne Animate Tokuten CD', 'cdncloudflare/files/music/anisong/1-animate-20260422-222737/cover.jpg', 'Tuyu', 0);
# SET @new_album_id = LAST_INSERT_ID();
# INSERT INTO musics (id_music, link_gdrive, title, artist, cover, uploader, is_suspicious, disc_number) VALUES
# (NULL, 'cdncloudflare/files/music/anisong/1-animate-20260422-222737/flac/01.mp3', 'Tsuyuake no (TUYU arrange ver.)', 'Tuyu', 'cdncloudflare/files/music/anisong/1-animate-20260422-222737/cover.jpg', 'Cybeat', 'false', '1');
# SET @first_new_song_id = LAST_INSERT_ID();
# INSERT INTO album_musics (id_playlist, id_music) VALUES
# (@new_album_id, @first_new_song_id + 0);
# INSERT INTO category_albums (album_id, category_id) VALUES
# (@new_album_id, 2);
#
# -- total file: 1
#
#
# -- 1 files
#
# INSERT INTO `albums` (`uid`, `name`, `image`, `author`, `have_disc`) VALUES
# (NULL, 'TV Anime Youkai Gakkou no Sensei Hajimemashita! ED Theme Song Bokurashisa / Yuika', 'cdncloudflare/files/music/anisong/1-bokurashisa-20260422-222737/Cover.jpg', 'Yuika', 0);
# SET @new_album_id = LAST_INSERT_ID();
# INSERT INTO musics (id_music, link_gdrive, title, artist, cover, uploader, is_suspicious, disc_number) VALUES
# (NULL, 'cdncloudflare/files/music/anisong/1-bokurashisa-20260422-222737/flac/01.flac', 'Bokurashisa', 'Yuika', 'cdncloudflare/files/music/anisong/1-bokurashisa-20260422-222737/Cover.jpg', 'Cybeat', 'false', '1');
# SET @first_new_song_id = LAST_INSERT_ID();
# INSERT INTO album_musics (id_playlist, id_music) VALUES
# (@new_album_id, @first_new_song_id + 0);
# INSERT INTO category_albums (album_id, category_id) VALUES
# (@new_album_id, 2);
#
# -- total file: 1
#
#
# -- 1 files
#
# INSERT INTO `albums` (`uid`, `name`, `image`, `author`, `have_disc`) VALUES
# (NULL, 'TV Anime "Blue Lock VS. U-20 JAPAN" OP Theme "Boujaku no Charisma" / UNISON SQUARE GARDEN', 'cdncloudflare/files/music/anisong/1-boujaku-no-charisma-20260422-222737/Cover_01.jpg', 'UNISON SQUARE GARDEN', 0);
# SET @new_album_id = LAST_INSERT_ID();
# INSERT INTO musics (id_music, link_gdrive, title, artist, cover, uploader, is_suspicious, disc_number) VALUES
# (NULL, 'cdncloudflare/files/music/anisong/1-boujaku-no-charisma-20260422-222737/flac/01.flac', 'Boujaku no Charisma', 'UNISON SQUARE GARDEN', 'cdncloudflare/files/music/anisong/1-boujaku-no-charisma-20260422-222737/Cover_01.jpg', 'Cybeat', 'false', '1');
# SET @first_new_song_id = LAST_INSERT_ID();
# INSERT INTO album_musics (id_playlist, id_music) VALUES
# (@new_album_id, @first_new_song_id + 0);
# INSERT INTO category_albums (album_id, category_id) VALUES
# (@new_album_id, 2);
#
# -- total file: 1
#
#
# -- 1 files
#
# INSERT INTO `albums` (`uid`, `name`, `image`, `author`, `have_disc`) VALUES
# (NULL, 'TV Anime "Youkai Gakkou no Sensei Hajimemashita!" OP Theme Song "Ebizori Turn!" / 48four8', 'cdncloudflare/files/music/anisong/1-ebizori-turn-20260422-222737/Cover.jpg', '48four8', 0);
# SET @new_album_id = LAST_INSERT_ID();
# INSERT INTO musics (id_music, link_gdrive, title, artist, cover, uploader, is_suspicious, disc_number) VALUES
# (NULL, 'cdncloudflare/files/music/anisong/1-ebizori-turn-20260422-222737/flac/01.flac', 'Ebizori Turn!', '48four8', 'cdncloudflare/files/music/anisong/1-ebizori-turn-20260422-222737/Cover.jpg', 'Cybeat', 'false', '1');
# SET @first_new_song_id = LAST_INSERT_ID();
# INSERT INTO album_musics (id_playlist, id_music) VALUES
# (@new_album_id, @first_new_song_id + 0);
# INSERT INTO category_albums (album_id, category_id) VALUES
# (@new_album_id, 2);
#
# -- total file: 1
#
#
# -- 1 files
#
# INSERT INTO `albums` (`uid`, `name`, `image`, `author`, `have_disc`) VALUES
# (NULL, 'TV Anime "Amagami-san Chi no Enmusubi" ED Theme Song "Kimi ni Koi wo Musunde" / Amagami Three Sisters', 'cdncloudflare/files/music/anisong/1-kimi-ni-koi-wo-musunde-20260422-222737/Cover.jpg', 'Amagami Three Sisters', 0);
# SET @new_album_id = LAST_INSERT_ID();
# INSERT INTO musics (id_music, link_gdrive, title, artist, cover, uploader, is_suspicious, disc_number) VALUES
# (NULL, 'cdncloudflare/files/music/anisong/1-kimi-ni-koi-wo-musunde-20260422-222737/flac/01.flac', 'Kimi ni Koi wo Musunde', 'Amagami Three Sisters', 'cdncloudflare/files/music/anisong/1-kimi-ni-koi-wo-musunde-20260422-222737/Cover.jpg', 'Cybeat', 'false', '1');
# SET @first_new_song_id = LAST_INSERT_ID();
# INSERT INTO album_musics (id_playlist, id_music) VALUES
# (@new_album_id, @first_new_song_id + 0);
# INSERT INTO category_albums (album_id, category_id) VALUES
# (@new_album_id, 2);
#
# -- total file: 1
#
#
# -- 1 files
#
# INSERT INTO `albums` (`uid`, `name`, `image`, `author`, `have_disc`) VALUES
# (NULL, 'Kanashimi Wo Yasashisa Ni', 'cdncloudflare/files/music/anisong/1-rainych-20260422-222737/art.jpg', 'Rainych', 0);
# SET @new_album_id = LAST_INSERT_ID();
# INSERT INTO musics (id_music, link_gdrive, title, artist, cover, uploader, is_suspicious, disc_number) VALUES
# (NULL, 'cdncloudflare/files/music/anisong/1-rainych-20260422-222737/flac/01.flac', 'Kanashimi Wo Yasashisa Ni', 'Rainych', 'cdncloudflare/files/music/anisong/1-rainych-20260422-222737/art.jpg', 'Cybeat', 'false', '1');
# SET @first_new_song_id = LAST_INSERT_ID();
# INSERT INTO album_musics (id_playlist, id_music) VALUES
# (@new_album_id, @first_new_song_id + 0);
# INSERT INTO category_albums (album_id, category_id) VALUES
# (@new_album_id, 2);
#
# -- total file: 1
#
#
# -- 1 files
#
# INSERT INTO `albums` (`uid`, `name`, `image`, `author`, `have_disc`) VALUES
# (NULL, 'TV Anime "Ranma 1/2 (2024)" OP Theme "Yoroshikunkyun" / ano', 'cdncloudflare/files/music/anisong/1-yoroshikunkyun-20260422-222737/Cover_01.jpg', 'ano', 0);
# SET @new_album_id = LAST_INSERT_ID();
# INSERT INTO musics (id_music, link_gdrive, title, artist, cover, uploader, is_suspicious, disc_number) VALUES
# (NULL, 'cdncloudflare/files/music/anisong/1-yoroshikunkyun-20260422-222737/flac/01.flac', 'Yoroshikunkyun', 'ano', 'cdncloudflare/files/music/anisong/1-yoroshikunkyun-20260422-222737/Cover_01.jpg', 'Cybeat', 'false', '1');
# SET @first_new_song_id = LAST_INSERT_ID();
# INSERT INTO album_musics (id_playlist, id_music) VALUES
# (@new_album_id, @first_new_song_id + 0);
# INSERT INTO category_albums (album_id, category_id) VALUES
# (@new_album_id, 2);
#
# -- total file: 1
#
#
# -- 2 files
#
# INSERT INTO `albums` (`uid`, `name`, `image`, `author`, `have_disc`) VALUES
# (NULL, 'TV Anime "Saikyou no Shienshoku [Wajutsushi] de Aru Ore wa Sekai Saikyou Clan wo Shitagaeru" ED Theme "Liberation" / KOHTA YAMAMOTO feat. AAAMYYY', 'cdncloudflare/files/music/anisong/2-liberation-20260422-222737/Cover.jpg', 'KOHTA YAMAMOTO feat. AAAMYYY', 0);
# SET @new_album_id = LAST_INSERT_ID();
# INSERT INTO musics (id_music, link_gdrive, title, artist, cover, uploader, is_suspicious, disc_number) VALUES
# (NULL, 'cdncloudflare/files/music/anisong/2-liberation-20260422-222737/flac/01.flac', 'Liberation (feat. AAAMYYY)', 'KOHTA YAMAMOTO feat. AAAMYYY', 'cdncloudflare/files/music/anisong/2-liberation-20260422-222737/Cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/anisong/2-liberation-20260422-222737/flac/02.flac', 'Liberation (feat. AAAMYYY) [Instrumental]', 'KOHTA YAMAMOTO feat. AAAMYYY', 'cdncloudflare/files/music/anisong/2-liberation-20260422-222737/Cover.jpg', 'Cybeat', 'false', '1');
# SET @first_new_song_id = LAST_INSERT_ID();
# INSERT INTO album_musics (id_playlist, id_music) VALUES
# (@new_album_id, @first_new_song_id + 0),
# (@new_album_id, @first_new_song_id + 1);
# INSERT INTO category_albums (album_id, category_id) VALUES
# (@new_album_id, 2);
#
# -- total file: 2
#
#
# -- 2 files
#
# INSERT INTO `albums` (`uid`, `name`, `image`, `author`, `have_disc`) VALUES
# (NULL, 'TV Anime "Touhai ~Ura Rate Mahjong Touhairoku~" ED Theme Song "Plastic Showcase" / Taiyou to Odore Tsukiyo ni utae', 'cdncloudflare/files/music/anisong/2-plastic-showcase-20260422-222737/Cover.jpg', 'Taiyou to Odore Tsukiyo ni utae', 0);
# SET @new_album_id = LAST_INSERT_ID();
# INSERT INTO musics (id_music, link_gdrive, title, artist, cover, uploader, is_suspicious, disc_number) VALUES
# (NULL, 'cdncloudflare/files/music/anisong/2-plastic-showcase-20260422-222737/flac/01.flac', 'Plastic Showcase', 'Taiyou to Odore Tsukiyo ni utae', 'cdncloudflare/files/music/anisong/2-plastic-showcase-20260422-222737/Cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/anisong/2-plastic-showcase-20260422-222737/flac/02.flac', 'Plastic Showcase (Instrumental)', 'Taiyou to Odore Tsukiyo ni utae', 'cdncloudflare/files/music/anisong/2-plastic-showcase-20260422-222737/Cover.jpg', 'Cybeat', 'false', '1');
# SET @first_new_song_id = LAST_INSERT_ID();
# INSERT INTO album_musics (id_playlist, id_music) VALUES
# (@new_album_id, @first_new_song_id + 0),
# (@new_album_id, @first_new_song_id + 1);
# INSERT INTO category_albums (album_id, category_id) VALUES
# (@new_album_id, 2);
#
# -- total file: 2
#
#
# -- 2 files
#
# INSERT INTO `albums` (`uid`, `name`, `image`, `author`, `have_disc`) VALUES
# (NULL, 'Movie "Blue Lock -EPISODE Nagi-" Theme Song "Stormy" / Nissy × SKY-HI', 'cdncloudflare/files/music/anisong/2-stormy-20260422-222737/Cover_01.jpg', 'Nissy × SKY-HI', 0);
# SET @new_album_id = LAST_INSERT_ID();
# INSERT INTO musics (id_music, link_gdrive, title, artist, cover, uploader, is_suspicious, disc_number) VALUES
# (NULL, 'cdncloudflare/files/music/anisong/2-stormy-20260422-222737/flac/01.flac', 'Stormy', 'Nissy × SKY-HI', 'cdncloudflare/files/music/anisong/2-stormy-20260422-222737/Cover_01.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/anisong/2-stormy-20260422-222737/flac/02.flac', 'Stormy (Inst)', 'Nissy × SKY-HI', 'cdncloudflare/files/music/anisong/2-stormy-20260422-222737/Cover_01.jpg', 'Cybeat', 'false', '1');
# SET @first_new_song_id = LAST_INSERT_ID();
# INSERT INTO album_musics (id_playlist, id_music) VALUES
# (@new_album_id, @first_new_song_id + 0),
# (@new_album_id, @first_new_song_id + 1);
# INSERT INTO category_albums (album_id, category_id) VALUES
# (@new_album_id, 2);
#
# -- total file: 2
#
#
# -- 4 files
#
# INSERT INTO `albums` (`uid`, `name`, `image`, `author`, `have_disc`) VALUES
# (NULL, 'TV Anime "Negaposi Angler" OP Theme "Ito" / Van de Shop ・ ED Theme "Shounin Yokkyuu" / 96Neko', 'cdncloudflare/files/music/anisong/4-ito-shounin-yokkyuu-20260422-222737/Cover.jpg', 'Van de Shop / 96Neko', 0);
# SET @new_album_id = LAST_INSERT_ID();
# INSERT INTO musics (id_music, link_gdrive, title, artist, cover, uploader, is_suspicious, disc_number) VALUES
# (NULL, 'cdncloudflare/files/music/anisong/4-ito-shounin-yokkyuu-20260422-222737/flac/01.flac', 'Ito', 'Van de Shop', 'cdncloudflare/files/music/anisong/4-ito-shounin-yokkyuu-20260422-222737/Cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/anisong/4-ito-shounin-yokkyuu-20260422-222737/flac/02.flac', 'Shounin Yokkyuu', '96Neko', 'cdncloudflare/files/music/anisong/4-ito-shounin-yokkyuu-20260422-222737/Cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/anisong/4-ito-shounin-yokkyuu-20260422-222737/flac/03.flac', 'Ito (instrumental)', 'Van de Shop', 'cdncloudflare/files/music/anisong/4-ito-shounin-yokkyuu-20260422-222737/Cover.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/anisong/4-ito-shounin-yokkyuu-20260422-222737/flac/04.flac', 'Shounin Yokkyuu (instrumental)', '96Neko', 'cdncloudflare/files/music/anisong/4-ito-shounin-yokkyuu-20260422-222737/Cover.jpg', 'Cybeat', 'false', '1');
# SET @first_new_song_id = LAST_INSERT_ID();
# INSERT INTO album_musics (id_playlist, id_music) VALUES
# (@new_album_id, @first_new_song_id + 0),
# (@new_album_id, @first_new_song_id + 1),
# (@new_album_id, @first_new_song_id + 2),
# (@new_album_id, @first_new_song_id + 3);
# INSERT INTO category_albums (album_id, category_id) VALUES
# (@new_album_id, 2);
#
# -- total file: 4
#
#
# -- 5 files
#
# INSERT INTO `albums` (`uid`, `name`, `image`, `author`, `have_disc`) VALUES
# (NULL, 'TV Anime "Re: Life in a different world from zero" Opening Theme - Redo / Konomi Suzuki', 'cdncloudflare/files/music/anisong/5-rezero-op1-redo-20260422-222737/cover.png', 'Konomi Suzuki', 0);
# SET @new_album_id = LAST_INSERT_ID();
# INSERT INTO musics (id_music, link_gdrive, title, artist, cover, uploader, is_suspicious, disc_number) VALUES
# (NULL, 'cdncloudflare/files/music/anisong/5-rezero-op1-redo-20260422-222737/flac/01.flac', 'Redo', 'Konomi Suzuki', 'cdncloudflare/files/music/anisong/5-rezero-op1-redo-20260422-222737/cover.png', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/anisong/5-rezero-op1-redo-20260422-222737/flac/02.flac', 'Mobius', 'Konomi Suzuki', 'cdncloudflare/files/music/anisong/5-rezero-op1-redo-20260422-222737/cover.png', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/anisong/5-rezero-op1-redo-20260422-222737/flac/03.flac', 'Sekai wa Kizu wo Dakishimeru (Acoustic ver.)', 'Konomi Suzuki', 'cdncloudflare/files/music/anisong/5-rezero-op1-redo-20260422-222737/cover.png', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/anisong/5-rezero-op1-redo-20260422-222737/flac/04.flac', 'Redo (instrumental)', 'Konomi Suzuki', 'cdncloudflare/files/music/anisong/5-rezero-op1-redo-20260422-222737/cover.png', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/anisong/5-rezero-op1-redo-20260422-222737/flac/05.flac', 'Mobius (instrumental)', 'Konomi Suzuki', 'cdncloudflare/files/music/anisong/5-rezero-op1-redo-20260422-222737/cover.png', 'Cybeat', 'false', '1');
# SET @first_new_song_id = LAST_INSERT_ID();
# INSERT INTO album_musics (id_playlist, id_music) VALUES
# (@new_album_id, @first_new_song_id + 0),
# (@new_album_id, @first_new_song_id + 1),
# (@new_album_id, @first_new_song_id + 2),
# (@new_album_id, @first_new_song_id + 3),
# (@new_album_id, @first_new_song_id + 4);
# INSERT INTO category_albums (album_id, category_id) VALUES
# (@new_album_id, 2);
#
# -- total file: 5
#
#
# -- 5 files
#
# INSERT INTO `albums` (`uid`, `name`, `image`, `author`, `have_disc`) VALUES
# (NULL, 'Sign', 'cdncloudflare/files/music/anisong/5-sign-20260422-222737/cover.png', 'FLOW', 0);
# SET @new_album_id = LAST_INSERT_ID();
# INSERT INTO musics (id_music, link_gdrive, title, artist, cover, uploader, is_suspicious, disc_number) VALUES
# (NULL, 'cdncloudflare/files/music/anisong/5-sign-20260422-222737/flac/01.flac', 'Sign', 'FLOW', 'cdncloudflare/files/music/anisong/5-sign-20260422-222737/cover.png', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/anisong/5-sign-20260422-222737/flac/02.flac', 'Nowhere - Kimi Ni Okuru Oreranari No Ouenka', 'FLOW', 'cdncloudflare/files/music/anisong/5-sign-20260422-222737/cover.png', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/anisong/5-sign-20260422-222737/flac/03.flac', 'Bring It on! (Reggaeton Mix)', 'FLOW', 'cdncloudflare/files/music/anisong/5-sign-20260422-222737/cover.png', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/anisong/5-sign-20260422-222737/flac/04.flac', 'Sign (Naruto Opening Mix)', 'FLOW', 'cdncloudflare/files/music/anisong/5-sign-20260422-222737/cover.png', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/anisong/5-sign-20260422-222737/flac/05.flac', 'Sign (Instrumental)', 'FLOW', 'cdncloudflare/files/music/anisong/5-sign-20260422-222737/cover.png', 'Cybeat', 'false', '1');
# SET @first_new_song_id = LAST_INSERT_ID();
# INSERT INTO album_musics (id_playlist, id_music) VALUES
# (@new_album_id, @first_new_song_id + 0),
# (@new_album_id, @first_new_song_id + 1),
# (@new_album_id, @first_new_song_id + 2),
# (@new_album_id, @first_new_song_id + 3),
# (@new_album_id, @first_new_song_id + 4);
# INSERT INTO category_albums (album_id, category_id) VALUES
# (@new_album_id, 2);
#
# -- total file: 5
#
# COMMIT; -- Kalau semua sukses
