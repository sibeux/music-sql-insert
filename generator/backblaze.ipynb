# %%
from dotenv import load_dotenv
import os
import requests
import boto3
import json
import datetime
from urllib.parse import quote, urlparse


load_dotenv()  # otomatis baca file .env di direktori sekarang

print('START TRANSACTION; -- Mulai transaction')

# 1. Konfigurasi Kredensial
s3 = boto3.client(
    's3',
    endpoint_url=os.getenv("URL_ENDPOINT"),
    aws_access_key_id=os.getenv("AWS_ACCESS_KEY_ID"),
    aws_secret_access_key=os.getenv(
        "AWS_SECRET_KEY_ID")
)

def escape_sql_string(value):
    # Escape single quotes by doubling them
    return value.replace("'", "`")

def escape_ampersand(url):
    # Sebelumnya ada return, dan harus dihapus agar semua karakter bisa dicheck.
    # Ini sebenarnya gak dipakai.
    if "&" in url:
        url = url.replace("&", "%26")
    if "☆" in url:
        url = url.replace("☆", "%E2%98%86")
    if " " in url:
        url = url.replace(" ", "%20")
    if "⁇" in url:
        url = url.replace("⁇", "%E2%81%87")
    if "’" in url:
        url = url.replace("’", "%E2%80%99")
    if "⁚" in url:
        url = url.replace("⁚", "%E2%81%9A")
    if "⁄" in url:
        url = url.replace("⁄", "%E2%81%84")
    return url

def escape_url(url):
    # Mengencode karakter khusus lainnya menggunakan urllib
    return quote(url, safe=":/")

def get_artist_from_title(title, list_title_artist):
    """Fungsi untuk mencocokkan judul dan menemukan artis yang sesuai."""
    for item in list_title_artist:
        # Pisahkan berdasarkan ' --- '
        song_title, artist = item.split(' --- ')
        if title.lower() == song_title.lower():  # Cocokkan tanpa memperhatikan huruf besar/kecil
            return artist
    return "Unknown Artist"  # Return "Unknown Artist" string jika tidak ditemukan


def get_match_title_from_name(title, list_index_title):
    """Fungsi untuk mencocokkan index dan menemukan judul yang sesuai."""
    for item in list_index_title:
        # Pisahkan berdasarkan ' --- '
        song_title, artist = item.split(' --- ')
        if title.lower() == song_title.lower():  # Cocokkan tanpa memperhatikan huruf besar/kecil
            return artist
    return "Unknown Title"  # Return "Unknown Title" string jika tidak ditemukan

def get_sql_query_insert_music(bucket_name, folder_target, folder_name):
    total_jumlah_file = 0
    # Daftar pasangan nama lagu dan artis
    list_title_artist = []
    # Daftar pasangan nama lagu dan index
    list_index_title = []
    list_cover = []

    category = ""
    artist = ""
    album_artist = ""
    album = ''

    is_dynamic_artist = False
    is_dynamic_title = False
    disc = 0

    # Collecting each row of values
    values = []
    playlist_value = []

    # Starting timestamp for date_added
    base_time = datetime.datetime.now().replace(microsecond=0)

    # Base SQL INSERT statement template
    insert_statement_template = "INSERT INTO musics (id_music, link_gdrive, title, artist, cover, uploader, is_suspicious, disc_number) VALUES \n"
    playlist_insert_statement_template = "INSERT INTO `albums` (`uid`, `name`, `image`, `author`, `have_disc`) VALUES \n"
    favorite = "0"

    try:
        # 2. Request Data (List Objects)
        response = s3.list_objects_v2(
            Bucket=bucket_name,
            Prefix=folder_target  # Ini filternya (mirip buka folder)
        )

        # 3. Parsing Hasil
        if 'Contents' in response:
            # Langsung ambil daftar cover image
            IMAGE_EXTS = {'.jpg', '.jpeg', '.png', '.webp'}
            # Masukkan ke dalam list_cover
            list_cover.extend(
                f"cdncloudflare/{(obj['Key'])}"
                for obj in response.get('Contents', [])
                if os.path.splitext(obj['Key'])[1].lower() in IMAGE_EXTS
                # Filter untuk memastikan cover image adalah main cover, bukan cover dari sub-folder.
                and (os.path.splitext(obj['Key'])[0]).split("/")[-2] == folder_name
            )
            # Setelah itu baru proses file musik
            for obj in response['Contents']:
                key = obj['Key']
                
                # Membersihkan nama file dari prefix agar terlihat rapi
                nama_file = key.replace(folder_target, "")
                
                # if nama_file: # Mencegah folder itu sendiri ikut terprint
                # print(f"- {key} (Size: {size} bytes) - {last_modified}")
                nama_file = key.replace(" ", "%20")
                # print(f"cdncloudflare/{nama_file}")
                if (".here.txt" in key):
                    txt_url = f"https://cdn.sibeux.my.id/{nama_file}"
                    response = requests.get(txt_url)
                    # Secara eksplisit set encoding ke 'utf-8' (agar teks non-alphabet bisa terbaca)
                    response.encoding = 'utf-8'
                    content = response.text
                    text_content = json.loads(content)
                    # Assign value ke variable album
                    category = text_content["category"]
                    album = text_content['title']
                    album = album.replace("'", "\'")
                    artist = text_content["author"]
                    album_artist = text_content["author"]
                    if text_content['disc'] != '0':
                        disc = int(text_content['disc']) - 1
                        if (text_content['1']) != []:
                            is_dynamic_artist = True
                            for i in range(disc+1):
                                list_title_artist.append(
                                    text_content[str(i+1)]
                                )
                    elif text_content['1'] != []:
                        is_dynamic_artist = True
                        list_title_artist.append(text_content["1"])
                    if text_content['music_name_index']['1'] != []:
                        is_dynamic_title = True
                        for i in range(disc+1):
                            list_index_title.append(
                                text_content['music_name_index'][str(i+1)]
                            )
                # Dapatkan cover image dari file yang ada di dalam folder
                ext = os.path.splitext(key)[1].lower()
                if ext in ['.mp3', '.flac', '.m4a', '.ogg', '.wav', '.acc', '.opus']:
                    music_url = f"cdncloudflare/{nama_file}"
                    final_title = ""
                    file_name_without_ext = os.path.splitext(
                        ((urlparse(key).path).split("/"))[-1])[0]
                    # cari artist berdasarkan nama file
                    if is_dynamic_artist:
                        if disc == 0:
                            artist = get_artist_from_title(
                                file_name_without_ext, list_title_artist[0])
                        else:
                            # pisah berdasar slash
                            parts = music_url.split("/")
                            number = int(parts[-2])  # elemen sebelum nama file
                            artist = get_artist_from_title(
                                file_name_without_ext, list_title_artist[number-1])
                    # Cari judul berdasarkan index
                    if is_dynamic_title:
                        if disc == 0:
                            title_song = get_match_title_from_name(file_name_without_ext, list_index_title[0])
                            title_song = title_song.replace("\'", "\\'")
                        else:
                            # pisah berdasar slash
                            parts = music_url.split("/")
                            number = int(parts[-2])  # elemen sebelum nama file
                            title_song = get_match_title_from_name(file_name_without_ext, list_index_title[number-1])
                            title_song = title_song.replace("\'", "\\'")
                    # Tambahkan 7 jam menggunakan timedelta
                    # date_added = base_time + datetime.timedelta(hours=7)
                    date_added = base_time + datetime.timedelta()
                    date_added_str = date_added.strftime("%Y-%m-%d %H:%M:%S")
                    # Escape special characters in the values
                    artist = escape_sql_string(artist)
                    album = escape_sql_string(album)
                    date_added_str = escape_sql_string(date_added_str)
                    if is_dynamic_title == True:
                        final_title = title_song
                    else:
                        final_title = file_name_without_ext
                    cover_link = list_cover[0]
                    path = urlparse(key).path
                    parts = path.split("/")
                    target = parts[-2]  # folder sebelum nama file
                    x = 1
                    if (target.lower() != 'flac'):
                        x = target
                    query = f"(NULL, '{music_url}', '{final_title}', '{artist}', '{cover_link}', 'Cybeat', 'false', '{x}')"
                    values.append(query)

        else:
            print("Folder kosong atau tidak ditemukan.")

    except Exception as e:
        print(f"Terjadi Error: {e}")

    # Buat query statement untuk insert album
    cover_link = list_cover[0]
    cover_link = escape_sql_string(cover_link)
    have_disc = 0
    if disc > 0:
        have_disc = 1
    playlist_value.append(
        f"(NULL, '{album}', '{cover_link}', '{album_artist}', {have_disc})"
    )

    # Joining all values into the final SQL INSERT statement
    playlist_insert_statement = playlist_insert_statement_template + \
        ",\n".join(playlist_value) + ";"
    insert_statement = insert_statement_template + \
        ",\n".join(values) + ";"

    jumlah_file = len(values)
    total_jumlah_file += jumlah_file
    print(f'\n-- {jumlah_file} files\n')
    print(playlist_insert_statement)
    print('SET @new_album_id = LAST_INSERT_ID();')
    print(insert_statement)
    print('SET @first_new_song_id = LAST_INSERT_ID();')
    album_music_insert_statement = 'INSERT INTO album_musics (id_playlist, id_music) VALUES\n'
    category_album_insert_statement = 'INSERT INTO category_albums (album_id, category_id) VALUES\n'
    album_music_value = []
    for index in range(jumlah_file):
        album_music_value.append(f'(@new_album_id, @first_new_song_id + {index})')
    print(album_music_insert_statement + \
        ",\n".join(album_music_value) + ";")
    print(category_album_insert_statement + \
        f"(@new_album_id, {category});")
    print(f'\n-- total file: {total_jumlah_file}\n')

with open('folder_list.txt', 'r') as f:
    folder_name = [line.strip() for line in f if line.strip()]
for index in range(len(folder_name)):
    folder_target = ''
    origin_folder_name = folder_name[index].replace("\\", "/").split('/')[1]
    # Akhiri dengan slash (/) untuk menandakan folder
    if folder_name[index][0] == '1':
        folder_target = f'files/music/indopride/{origin_folder_name}/'
    elif folder_name[index][0] == '2':
        folder_target = f'files/music/anisong/{origin_folder_name}/'
    elif folder_name[index][0] == '4':
        folder_target = f'files/music/worldwide/{origin_folder_name}/'
    elif folder_name[index][0] == '5':
        folder_target = f'files/music/instrumental/{origin_folder_name}/'
    bucket_name = 'cybeat-sibeux'
    get_sql_query_insert_music(bucket_name, folder_target, origin_folder_name)
print('COMMIT; -- Kalau semua sukses')
# ROLLBACK -- Kalau ada error di tengah2
# Out:
# START TRANSACTION; -- Mulai transaction
#
# -- 52 files
#
# INSERT INTO `albums` (`uid`, `name`, `image`, `author`, `have_disc`) VALUES
# (NULL, 'One Piece 25th Anniversary BEST 1999-2024', 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/Cover-min.jpg', 'Various Artist', 1);
# SET @new_album_id = LAST_INSERT_ID();
# INSERT INTO musics (id_music, link_gdrive, title, artist, cover, uploader, is_suspicious, disc_number) VALUES
# (NULL, 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/1/01.opus', 'We Are!', 'Hiroshi Kitadani', 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/Cover-min.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/1/02.opus', 'Believe', 'Folder5', 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/Cover-min.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/1/03.opus', 'Towards the Light', 'The babystars', 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/Cover-min.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/1/04.opus', 'BON VOYAGE!', 'BON-BON BLANCO', 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/Cover-min.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/1/05.opus', 'Map of the Heart', 'BOYSTYLE', 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/Cover-min.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/1/06.opus', 'BRAND NEW WORLD', 'D-51', 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/Cover-min.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/1/07.opus', 'We Are! ~7 Straw Hats Version~', '7 Straw Hats (Mayumi Tanaka, Kappei Yamaguchi, Hiroaki Hirata, Kazuya Nakai, Akemi Okamura, Ikue Ohtani, Yuriko Yamaguchi)', 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/Cover-min.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/1/08.opus', 'Crazy Rainbow', 'Tackey & Tsubasa', 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/Cover-min.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/1/09.opus', 'Jungle P', '5050', 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/Cover-min.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/1/10.opus', 'Search for the Wind', 'Mari Yaguchi with Straw Hat', 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/Cover-min.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/1/11.opus', 'One day', 'The ROOTLESS', 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/Cover-min.jpg', 'Cybeat', 'false', '1'),
# (NULL, 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/2/01.opus', 'We Go!', 'Hiroshi Kitadani', 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/Cover-min.jpg', 'Cybeat', 'false', '2'),
# (NULL, 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/2/02.opus', 'HANDS UP!', 'Kota Shinzato', 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/Cover-min.jpg', 'Cybeat', 'false', '2'),
# (NULL, 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/2/03.opus', 'Wake up!', 'AAA', 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/Cover-min.jpg', 'Cybeat', 'false', '2'),
# (NULL, 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/2/04.opus', 'Hard Knock Days', 'GENERATIONS from EXILE TRIBE', 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/Cover-min.jpg', 'Cybeat', 'false', '2'),
# (NULL, 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/2/05.opus', 'We Can!', 'Kishidan, Hiroshi Kitadani', 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/Cover-min.jpg', 'Cybeat', 'false', '2'),
# (NULL, 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/2/06.opus', 'Super Powers', 'V6', 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/Cover-min.jpg', 'Cybeat', 'false', '2'),
# (NULL, 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/2/07.opus', 'OVER THE TOP', 'Hiroshi Kitadani', 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/Cover-min.jpg', 'Cybeat', 'false', '2'),
# (NULL, 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/2/08.opus', 'DREAMIN\' ON', 'Da-iCE', 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/Cover-min.jpg', 'Cybeat', 'false', '2'),
# (NULL, 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/2/09.opus', 'PAINT', 'I Don`t Like Mondays.', 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/Cover-min.jpg', 'Cybeat', 'false', '2'),
# (NULL, 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/2/10.opus', 'The Peak', 'SEKAI NO OWARI', 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/Cover-min.jpg', 'Cybeat', 'false', '2'),
# (NULL, 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/2/11.opus', 'UUUUUS!', 'Hiroshi Kitadani', 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/Cover-min.jpg', 'Cybeat', 'false', '2'),
# (NULL, 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/2/12.opus', 'We Are! ~9 Straw Hats Version~', '9 Straw Hats (Mayumi Tanaka, Kazuya Nakai, Akemi Okamura, Kappei Yamaguchi, Hiroaki Hirata, Ikue Ohtani, Yuriko Yamaguchi, Kazuki Yao, Cho)', 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/Cover-min.jpg', 'Cybeat', 'false', '2'),
# (NULL, 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/2/13.opus', 'We Were!', 'Nise Luffy (CV: Hiroaki Hirata)', 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/Cover-min.jpg', 'Cybeat', 'false', '2'),
# (NULL, 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/2/14.opus', 'We Are! ~Mugiwara no Ichimi ver.~', 'Straw Hat', 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/Cover-min.jpg', 'Cybeat', 'false', '2'),
# (NULL, 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/2/15.opus', 'We Are! -From THE FIRST TAKE-', 'Hiroshi Kitadani', 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/Cover-min.jpg', 'Cybeat', 'false', '2'),
# (NULL, 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/3/01.opus', 'memories', 'Maki Otsuki', 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/Cover-min.jpg', 'Cybeat', 'false', '3'),
# (NULL, 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/3/02.opus', 'RUN!RUN!RUN!', 'Maki Otsuki', 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/Cover-min.jpg', 'Cybeat', 'false', '3'),
# (NULL, 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/3/03.opus', 'You\'ve Got Me', 'TOMATO CUBE', 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/Cover-min.jpg', 'Cybeat', 'false', '3'),
# (NULL, 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/3/04.opus', 'That\'s a Fact!', 'Suitei Shojo', 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/Cover-min.jpg', 'Cybeat', 'false', '3'),
# (NULL, 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/3/05.opus', 'BEFORE DAWN', 'AI-SACHI', 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/Cover-min.jpg', 'Cybeat', 'false', '3'),
# (NULL, 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/3/06.opus', 'fish', 'The Kaleidoscope', 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/Cover-min.jpg', 'Cybeat', 'false', '3'),
# (NULL, 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/3/07.opus', 'GLORY -Because You\'re Here-', 'Takako Uehara', 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/Cover-min.jpg', 'Cybeat', 'false', '3'),
# (NULL, 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/3/08.opus', 'Shining ray', 'Janne da Arc', 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/Cover-min.jpg', 'Cybeat', 'false', '3'),
# (NULL, 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/3/09.opus', 'Free Will', 'Ruppina', 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/Cover-min.jpg', 'Cybeat', 'false', '3'),
# (NULL, 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/3/10.opus', 'FAITH', 'Ruppina', 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/Cover-min.jpg', 'Cybeat', 'false', '3'),
# (NULL, 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/4/01.opus', 'A to Z~ONE PIECE Edition~', 'ZZ', 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/Cover-min.jpg', 'Cybeat', 'false', '4'),
# (NULL, 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/4/02.opus', 'Moon and Sun', 'shela', 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/Cover-min.jpg', 'Cybeat', 'false', '4'),
# (NULL, 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/4/03.opus', 'DREAMSHIP', 'Aiko☆Ikuta', 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/Cover-min.jpg', 'Cybeat', 'false', '4'),
# (NULL, 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/4/04.opus', 'Future Voyage', 'Tackey & Tsubasa', 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/Cover-min.jpg', 'Cybeat', 'false', '4'),
# (NULL, 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/4/05.opus', 'Eternal Pose', 'ASIA ENGINEER', 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/Cover-min.jpg', 'Cybeat', 'false', '4'),
# (NULL, 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/4/06.opus', 'Dear friends', 'TRIPLANE', 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/Cover-min.jpg', 'Cybeat', 'false', '4'),
# (NULL, 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/4/07.opus', 'ADVENTURE WORLD', 'Delicatessen', 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/Cover-min.jpg', 'Cybeat', 'false', '4'),
# (NULL, 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/4/08.opus', 'Raise', 'Chilli Beans.', 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/Cover-min.jpg', 'Cybeat', 'false', '4'),
# (NULL, 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/4/09.opus', 'Dear sunrise', 'Maki Otsuki', 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/Cover-min.jpg', 'Cybeat', 'false', '4'),
# (NULL, 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/4/10.opus', 'Family ~6 Straw Hats Version~', '6 Straw Hats (Mayumi Tanaka, Kappei Yamaguchi, Hiroaki Hirata, Kazuya Nakai, Akemi Okamura, Ikue Ohtani)', 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/Cover-min.jpg', 'Cybeat', 'false', '4'),
# (NULL, 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/4/11.opus', 'Family ~7 Straw Hats Version~', '7 Straw Hats (Mayumi Tanaka, Kappei Yamaguchi, Hiroaki Hirata, Kazuya Nakai, Akemi Okamura, Ikue Ohtani, Yuriko Yamaguchi)', 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/Cover-min.jpg', 'Cybeat', 'false', '4'),
# (NULL, 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/4/12.opus', 'Family ~9 Straw Hats Version~', '9 Straw Hats (Mayumi Tanaka, Kazuya Nakai, Akemi Okamura, Kappei Yamaguchi, Hiroaki Hirata, Ikue Ohtani, Yuriko Yamaguchi, Kazuki Yao, Cho)', 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/Cover-min.jpg', 'Cybeat', 'false', '4'),
# (NULL, 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/4/13.opus', 'Family ~10 Straw Hats Version~', '10 Straw Hats (Mayumi Tanaka, Kazuya Nakai, Akemi Okamura, Kappei Yamaguchi, Hiroaki Hirata, Ikue Ohtani, Yuriko Yamaguchi, Kazuki Yao, Cho, Katsuhisa Houki)', 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/Cover-min.jpg', 'Cybeat', 'false', '4'),
# (NULL, 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/4/14.opus', 'Binks\' Sake', '9 Straw Hats (Mayumi Tanaka, Kazuya Nakai, Akemi Okamura, Kappei Yamaguchi, Hiroaki Hirata, Kazuki Yao, Ikue Ohtani, Kazuki Yao, Cho)', 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/Cover-min.jpg', 'Cybeat', 'false', '4'),
# (NULL, 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/4/15.opus', 'Binks\' Sake', 'Brook (Cho)', 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/Cover-min.jpg', 'Cybeat', 'false', '4'),
# (NULL, 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/4/16.opus', 'Binks\' Sake', 'Roger Pirates', 'cdncloudflare/files/music/anisong/52-op-25-best-20260601-081526/Cover-min.jpg', 'Cybeat', 'false', '4');
# SET @first_new_song_id = LAST_INSERT_ID();
# INSERT INTO album_musics (id_playlist, id_music) VALUES
# (@new_album_id, @first_new_song_id + 0),
# (@new_album_id, @first_new_song_id + 1),
# (@new_album_id, @first_new_song_id + 2),
# (@new_album_id, @first_new_song_id + 3),
# (@new_album_id, @first_new_song_id + 4),
# (@new_album_id, @first_new_song_id + 5),
# (@new_album_id, @first_new_song_id + 6),
# (@new_album_id, @first_new_song_id + 7),
# (@new_album_id, @first_new_song_id + 8),
# (@new_album_id, @first_new_song_id + 9),
# (@new_album_id, @first_new_song_id + 10),
# (@new_album_id, @first_new_song_id + 11),
# (@new_album_id, @first_new_song_id + 12),
# (@new_album_id, @first_new_song_id + 13),
# (@new_album_id, @first_new_song_id + 14),
# (@new_album_id, @first_new_song_id + 15),
# (@new_album_id, @first_new_song_id + 16),
# (@new_album_id, @first_new_song_id + 17),
# (@new_album_id, @first_new_song_id + 18),
# (@new_album_id, @first_new_song_id + 19),
# (@new_album_id, @first_new_song_id + 20),
# (@new_album_id, @first_new_song_id + 21),
# (@new_album_id, @first_new_song_id + 22),
# (@new_album_id, @first_new_song_id + 23),
# (@new_album_id, @first_new_song_id + 24),
# (@new_album_id, @first_new_song_id + 25),
# (@new_album_id, @first_new_song_id + 26),
# (@new_album_id, @first_new_song_id + 27),
# (@new_album_id, @first_new_song_id + 28),
# (@new_album_id, @first_new_song_id + 29),
# (@new_album_id, @first_new_song_id + 30),
# (@new_album_id, @first_new_song_id + 31),
# (@new_album_id, @first_new_song_id + 32),
# (@new_album_id, @first_new_song_id + 33),
# (@new_album_id, @first_new_song_id + 34),
# (@new_album_id, @first_new_song_id + 35),
# (@new_album_id, @first_new_song_id + 36),
# (@new_album_id, @first_new_song_id + 37),
# (@new_album_id, @first_new_song_id + 38),
# (@new_album_id, @first_new_song_id + 39),
# (@new_album_id, @first_new_song_id + 40),
# (@new_album_id, @first_new_song_id + 41),
# (@new_album_id, @first_new_song_id + 42),
# (@new_album_id, @first_new_song_id + 43),
# (@new_album_id, @first_new_song_id + 44),
# (@new_album_id, @first_new_song_id + 45),
# (@new_album_id, @first_new_song_id + 46),
# (@new_album_id, @first_new_song_id + 47),
# (@new_album_id, @first_new_song_id + 48),
# (@new_album_id, @first_new_song_id + 49),
# (@new_album_id, @first_new_song_id + 50),
# (@new_album_id, @first_new_song_id + 51);
# INSERT INTO category_albums (album_id, category_id) VALUES
# (@new_album_id, 2);
#
# -- total file: 52
#
# COMMIT; -- Kalau semua sukses
